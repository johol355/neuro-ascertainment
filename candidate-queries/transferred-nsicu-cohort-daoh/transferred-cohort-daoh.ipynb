# %%
# Load dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sqlalchemy
from sqlalchemy import create_engine, text
import pymc as pm
import arviz as az
from scipy.stats import zscore

# Define the SQLalchemy engine
engine = create_engine(f"sqlite:////Users/JO/PhD/datauttag/2025/db_2025.sqlite")

# Read the SQL query from the file
with open('/Users/JO/PhD/neuro-ascertainment/candidate-queries/transferred-nsicu-cohort-daoh/transferred-cohort-daoh.sql', 'r') as file:
    query = file.read()

SEED = 20
rng = np.random.default_rng(SEED)

def count_id(df):
    LopNr = df['LopNr'].nunique() if 'LopNr' in df else 'Column missing'
    VtfId_LopNr = df['VtfId_LopNr'].nunique() if 'VtfId_LopNr' in df else 'Column missing'
    HADM_ID = df['HADM_ID'].nunique() if 'HADM_ID' in df else 'Column missing'
    return print(f'Unique patients: {LopNr} | Unique SIR admits: {VtfId_LopNr} | Unique PAR admits: {HADM_ID}')

# %%
q = query + "SELECT * FROM FINAL"
d = pd.read_sql(q, engine)

# %%
d.DX_GROUP
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4          TBI
#           ...
# 109102     AIS
# 109103    None
# 109104    None
# 109105    None
# 109106    None
# Name: DX_GROUP, Length: 109107, dtype: object

# %%
d.DX_RANK
# Out:
# 0         15
# 1         15
# 2         15
# 3         15
# 4          5
#           ..
# 109102     6
# 109103    15
# 109104    15
# 109105    15
# 109106    15
# Name: DX_RANK, Length: 109107, dtype: int64

# %%
d[["SAPS_total_score", "SAPS_score_minus_gcs", "SAPS_score_minus_age", "SAPS_score_minus_age_and_gcs", "age", "sir_consciousness_level"]]
# Out:
#         SAPS_total_score  SAPS_score_minus_gcs  SAPS_score_minus_age  \
# 0                   74.0                  74.0                   NaN
# 1                   69.0                  67.0                   NaN
# 2                   67.0                  65.0                   NaN
# 3                    NaN                   NaN                   NaN
# 4                   71.0                  56.0                  66.0
# ...                  ...                   ...                   ...
# 109102              74.0                  64.0                  59.0
# 109103              41.0                  41.0                   NaN
# 109104              80.0                  65.0                   NaN
# 109105              65.0                  65.0                   NaN
# 109106              55.0                  55.0                   NaN
#
#         SAPS_score_minus_age_and_gcs   age sir_consciousness_level
# 0                                NaN   NaN             I (GCS ≥13)
# 1                                NaN   NaN           II (GCS 7-12)
# 2                                NaN   NaN           II (GCS 7-12)
# 3                                NaN   NaN                    None
# 4                               51.0  48.0              V (GCS ≤4)
# ...                              ...   ...                     ...
# 109102                          49.0  79.0              IV (GCS 5)
# 109103                           NaN   NaN             I (GCS ≥13)
# 109104                           NaN   NaN              V (GCS ≤4)
# 109105                           NaN   NaN             I (GCS ≥13)
# 109106                           NaN   NaN             I (GCS ≥13)
#
# [109107 rows x 6 columns]

# %%
count_id(final)
# Out:
# Unique patients: 8849 | Unique SIR admits: 8849 | Unique PAR admits: 8849

# %%
final.query("AvdNamn == 'Bollnäs'").sort_values(by="YEAR").tail(35)
# Out:
#         VtfId_LopNr   HADM_ID        LopNr  InskrTidpunkt  UtskrTidpunkt  \
# 15961      180384.0   66043.0      44730.0     1632160200     1632167100
# 31824      182331.0   18389.0      12388.0     1641032400     1641036900
# 43007      182758.0    7609.0       4954.0     1642739400     1642747800
# 76882      184083.0   37361.0      25471.0     1649167200     1649184000
# 41565      184597.0   87933.0      59933.0     1651513560     1651519800
# 98302     2104036.0  126716.0  388339268.0     1661530200     1661541600
# 95735     2104330.0  123242.0  344496071.0     1662855000     1662864360
# 98708     2104510.0  126045.0  379839554.0     1663791600     1663846200
# 99551     2105655.0   95546.0    7948927.0     1669312800     1669318200
# 101148    2107803.0  125778.0  375656541.0     1679601600     1679608800
# 102025    2108942.0  121467.0  323447337.0     1685470800     1685475900
# 102080    2109052.0  126050.0  379991076.0     1685982300     1685984700
# 102089    2109064.0  102678.0   95434500.0     1686068100     1686076200
# 102342    2109468.0  133760.0  473125300.0     1687851000     1687856400
# 102603    2109784.0  121346.0  321935514.0     1689587400     1689597000
# 97133     2110917.0  110624.0  187965733.0     1694781900     1694787000
# 103680    2111326.0  119629.0  301221453.0     1696739400     1696745400
# 93168     2111486.0  113622.0  226473060.0     1697425200     1697431500
# 103950    2111727.0  112451.0  211766567.0     1698692400     1698694800
# 104258    2112184.0  121521.0  324193739.0     1700602500     1700607900
# 97287     2112788.0  101921.0   87096811.0     1703342700     1703350200
# 104763    2112858.0  112430.0  211481649.0     1703801400     1703805000
# 105220    2113395.0  107535.0  149467295.0     1706640900     1706649600
# 105255    2113471.0  119185.0  294757515.0     1707077400     1707127200
# 105475    2113830.0  129329.0  417582872.0     1708179600     1708190400
# 106048    2114618.0  128171.0  405404670.0     1712404200     1712410800
# 106593    2115495.0  105161.0  122979046.0     1716843600     1716852000
# 106952    2116077.0  127311.0  395260457.0     1719654000     1719660600
# 107559    2116848.0   99855.0   62359157.0     1723677300     1723713000
# 107909    2117439.0  124782.0  362548476.0     1726164600     1726171200
# 108037    2117579.0  109262.0  171103153.0     1726877100     1726929000
# 108090    2117657.0  102890.0   97705687.0     1727295000     1727306100
# 108141    2117751.0  136018.0  499627801.0     1727718300     1727724900
# 108388    2118184.0  111508.0  200531923.0     1729615500     1729618200
# 108508    2118451.0  123274.0  344675933.0     1730910600     1730915460
#
#         AvdNamn  INDATUM  UTDATUM SJUKHUS  MVO  SIR_PAR_OFFSET  \
# 15961   Bollnäs  18890.0  18901.0   12001  331             0.0
# 31824   Bollnäs  18993.0  18994.0   12001  109             0.0
# 43007   Bollnäs  19013.0  19032.0   12001  331             0.0
# 76882   Bollnäs  19087.0  19094.0   12001  331             0.0
# 41565   Bollnäs  19114.0  19118.0   12001  331             0.0
# 98302   Bollnäs  19230.0  19237.0   12001  331             0.0
# 95735   Bollnäs  19246.0  19247.0   12001  109             0.0
# 98708   Bollnäs  19257.0  19262.0   12001  331             0.0
# 99551   Bollnäs  19320.0  19334.0   12001  331             0.0
# 101148  Bollnäs  19439.0  19459.0   12001  331             0.0
# 102025  Bollnäs  19507.0  19525.0   12001  331             0.0
# 102080  Bollnäs  19513.0  19519.0   12001  109             0.0
# 102089  Bollnäs  19514.0  19515.0   12001  109             0.0
# 102342  Bollnäs  19535.0  19536.0   12001  109             0.0
# 102603  Bollnäs  19555.0  19574.0   12001  331             0.0
# 97133   Bollnäs  19615.0  19618.0   12001  109             0.0
# 103680  Bollnäs  19638.0  19642.0   12001  109             0.0
# 93168   Bollnäs  19646.0  19648.0   12001  109             0.0
# 103950  Bollnäs  19660.0  19663.0   12001  331             0.0
# 104258  Bollnäs  19682.0  19698.0   12001  331             0.0
# 97287   Bollnäs  19714.0  19725.0   12001  331             0.0
# 104763  Bollnäs  19720.0  19721.0   12001  109            -1.0
# 105220  Bollnäs  19752.0  19754.0   12001  109             0.0
# 105255  Bollnäs  19758.0  19775.0   12001  331             0.0
# 105475  Bollnäs  19770.0  19783.0   12001  331             0.0
# 106048  Bollnäs  19819.0  19822.0   12001  109             0.0
# 106593  Bollnäs  19871.0  19889.0   12001  331            -1.0
# 106952  Bollnäs  19903.0  19905.0   12001  109             0.0
# 107559  Bollnäs  19950.0  19951.0   12001  331             0.0
# 107909  Bollnäs  19978.0  19981.0   12001  109             0.0
# 108037  Bollnäs  19987.0  19989.0   12001  331             0.0
# 108090  Bollnäs  19992.0  20005.0   12001  331            -1.0
# 108141  Bollnäs  19996.0  20004.0   12001  331             0.0
# 108388  Bollnäs  20018.0  20019.0   12001  221             0.0
# 108508  Bollnäs  20033.0  20043.0   12001  331             0.0
#
#         SIR_PAR_OFFSET_TIGHT  OREBRO_INTERNAL  \
# 15961                    0.0                0
# 31824                    0.0                0
# 43007                    0.0                0
# 76882                    0.0                0
# 41565                    0.0                0
# 98302                    0.0                0
# 95735                    0.0                0
# 98708                    0.0                0
# 99551                    0.0                0
# 101148                   0.0                0
# 102025                   0.0                0
# 102080                   0.0                0
# 102089                   0.0                0
# 102342                   0.0                0
# 102603                   0.0                0
# 97133                    0.0                0
# 103680                   0.0                0
# 93168                    0.0                0
# 103950                   0.0                0
# 104258                   0.0                0
# 97287                    0.0                0
# 104763                  -1.0                0
# 105220                   0.0                0
# 105255                   0.0                0
# 105475                   0.0                0
# 106048                   0.0                0
# 106593                  -1.0                0
# 106952                   0.0                0
# 107559                   0.0                0
# 107909                   0.0                0
# 108037                   0.0                0
# 108090                  -1.0                0
# 108141                   0.0                0
# 108388                   0.0                0
# 108508                   0.0                0
#
#                                                   Diagnos DX_GROUP  DX_RANK  \
# 15961   G001 H700 R568X G628 G819 I693 C679 I109 E119 ...      ABM        7
# 31824   I639 I489 I495 Z950 R739                               AIS        6
# 43007       I609 R908 J981 R509                               ASAH        1
# 76882   I676 I612 I490 R568X E119 F102                ...      CVT        8
# 41565   I614 D683 J958A I513 E119 Z955 I252           ...      ICH        4
# 98302           Q282 T817 I633                                 AVM        3
# 95735      I639 I489 Z867C I429                                AIS        6
# 98708   S0650 E119 I109 I450A I440                    ...      TBI        5
# 99551       I604 A492 I489 F171                               ASAH        1
# 101148  I606 J958A B964 J819 I109 C919                ...     ASAH        1
# 102025  S066 S065 S068 R568X K053 E785                ...      TBI        5
# 102080  I630 R470 G819 R139 J690 I109 H810 Z853       ...      AIS        6
# 102089          I639 I109 N199                                 AIS        6
# 102342      I630 T810 I612 I607                                AIS        6
# 102603  I602 I671 T817 I724 F172                              ASAH        1
# 97133               I630 I652                                  AIS        6
# 103680  I639 I670 I726 T810 I613 D683 G912            ...      AIS        6
# 93168   I639 I653 G835 I109 E039 E109 Z867C           ...      AIS        6
# 103950         S0650 G409 E119                                 TBI        5
# 104258  I605 T825 T857 G039 I109 J449 M069 U071       ...     ASAH        1
# 97287          I612 F900B Z860                                 ICH        4
# 104763  I630 I652 R470A R201 E780                     ...      AIS        6
# 105220      I634 I489 I109 R470                                AIS        6
# 105255  G002 B950 H660 H729 H700 G419 N179 I109 K512 F...      ABM        7
# 105475          I611 I671 T818                                ASAH        1
# 106048  I639 I219 I509 J690 S3250 F039                ...      AIS        6
# 106593          I609 G003 R398                                ASAH        1
# 106952  I634 R139 R298 G819 I489 I509 Z955            ...      AIS        6
# 107559              I620 E119                                  SDH       12
# 107909  I639 I109 Z867C S065 T812                     ...      AIS        6
# 108037              S065 N409                                  TBI        5
# 108090  I614 J019 B961 I109 E119 Z854J                ...      ICH        4
# 108141          I638 I726 G911                                 AIS        6
# 108388      I639 I109 I723 T810                                AIS        6
# 108508  I602 D683 I472A I493 I109 E785 Z955 I252      ...     ASAH        1
#
#                       YEAR
# 15961  2021-09-20 17:50:00
# 31824  2022-01-01 10:20:00
# 43007  2022-01-21 04:30:00
# 76882  2022-04-05 14:00:00
# 41565  2022-05-02 17:46:00
# 98302  2022-08-26 16:10:00
# 95735  2022-09-11 00:10:00
# 98708  2022-09-21 20:20:00
# 99551  2022-11-24 18:00:00
# 101148 2023-03-23 20:00:00
# 102025 2023-05-30 18:20:00
# 102080 2023-06-05 16:25:00
# 102089 2023-06-06 16:15:00
# 102342 2023-06-27 07:30:00
# 102603 2023-07-17 09:50:00
# 97133  2023-09-15 12:45:00
# 103680 2023-10-08 04:30:00
# 93168  2023-10-16 03:00:00
# 103950 2023-10-30 19:00:00
# 104258 2023-11-21 21:35:00
# 97287  2023-12-23 14:45:00
# 104763 2023-12-28 22:10:00
# 105220 2024-01-30 18:55:00
# 105255 2024-02-04 20:10:00
# 105475 2024-02-17 14:20:00
# 106048 2024-04-06 11:50:00
# 106593 2024-05-27 21:00:00
# 106952 2024-06-29 09:40:00
# 107559 2024-08-14 23:15:00
# 107909 2024-09-12 18:10:00
# 108037 2024-09-21 00:05:00
# 108090 2024-09-25 20:10:00
# 108141 2024-09-30 17:45:00
# 108388 2024-10-22 16:45:00
# 108508 2024-11-06 16:30:00

# %%
final.query("DX_GROUP == 'AVM'").query("AvdNamn == 'Östersund'")
# Out:
#        VtfId_LopNr  HADM_ID    LopNr  InskrTidpunkt  UtskrTidpunkt    AvdNamn  \
# 89295     161905.0  66629.0  45149.0     1551639000     1551656520  Östersund
#
#        INDATUM  UTDATUM SJUKHUS  MVO  SIR_PAR_OFFSET  SIR_PAR_OFFSET_TIGHT  \
# 89295  17959.0  17967.0   64001  331            -1.0                  -1.0
#
#        OREBRO_INTERNAL                                        Diagnos  \
# 89295                0  Q282 B956 J690 Q872
#
#       DX_GROUP  DX_RANK  YEAR
# 89295      AVM        3  2019

# %% [markdown]
# ### PAR_HADM
# This is the PAR table with an identifer ID for each admission.

# %%
query_PAR_HADM = query + "SELECT * FROM PAR_HADM"
PAR_HADM = pd.read_sql(query_PAR_HADM, engine)
count_id(PAR_HADM)
# Out:
# Unique patients: 54147 | Unique SIR admits: 64550 | Unique PAR admits: Column missing

# %% [markdown]
# ### PR_ICU_ADMISSIONS
# "Primary ICU admissions". SIR admissions in ICUs at a hospital without NSICU capacity (i.e. mainly primary (länsdelssjukhus) and secondary (länssjukhus) hospitals).

# %%
query_PR_ICU_ADMISSIONS = query + "SELECT * FROM PR_ICU_ADMISSIONS"
PR_ICU_ADMISSIONS = pd.read_sql(query_PR_ICU_ADMISSIONS, engine)
count_id(PR_ICU_ADMISSIONS)
# Out:
# Unique patients: 26518 | Unique SIR admits: 28822 | Unique PAR admits: Column missing

# %% [markdown]
# ### PR_ICU_ADMISSIONS_MATCHED_WITH_PAR
# Primary ICU admissions matched with PAR admissions at university hospitals (any department, any dx) +/- 1 day of primary ICU discharge.

# %%
query_PR_ICU_ADMISSIONS_MATCHED_WITH_PAR = query + "SELECT * FROM PR_ICU_ADMISSIONS_MATCHED_WITH_PAR"
PR_ICU_ADMISSIONS_MATCHED_WITH_PAR = pd.read_sql(query_PR_ICU_ADMISSIONS_MATCHED_WITH_PAR, engine)
count_id(PR_ICU_ADMISSIONS_MATCHED_WITH_PAR)
# Out:
# Unique patients: 8206 | Unique SIR admits: 8381 | Unique PAR admits: 8841

# %%
PR_ICU_ADMISSIONS_MATCHED_WITH_PAR.head(3)
# Out:
#    VtfId_LopNr  HADM_ID    LopNr  InskrTidPunkt  UtskrTidPunkt     AvdNamn  \
# 0     175633.0   186729  33694.0     1610590020     1610648400      STGIVA
# 1     175640.0   203729  36615.0     1610658000     1610673300  SU/IVA-INF
# 2     175646.0   276169  49700.0     1610711100     1610721000    Västerås
#
#    INDATUM  UTDATUM  MVO SJUKHUS
# 0    18641    18668  331   11003
# 1    18641    18642  121   51001
# 2    18642    18654  331   12001

# %% [markdown]
# ### PR_ICU_ADMISSIONS_MATCHED_WITH_PAR_WITH_DX
# Adds inferred diagnostic group to the PR_ICU_ADMISSIONS_MATCHED_WITH_PAR table for each PAR admission.

# %%
query_PR_ICU_ADMISSIONS_MATCHED_WITH_PAR_WITH_DX = query + "SELECT * FROM PR_ICU_ADMISSIONS_MATCHED_WITH_PAR_WITH_DX"
PR_ICU_ADMISSIONS_MATCHED_WITH_PAR_WITH_DX = pd.read_sql(query_PR_ICU_ADMISSIONS_MATCHED_WITH_PAR_WITH_DX, engine)
count_id(PR_ICU_ADMISSIONS_MATCHED_WITH_PAR_WITH_DX)
# Out:
# Unique patients: 8206 | Unique SIR admits: 8381 | Unique PAR admits: 8841

# %% [markdown]
# ### PR_ICU_ADMISSIONS_MATCHED_WITH_PAR_WITH_DX_TIME_HIERARCHY
# Ranks matched PAR admissions for each primary ICU admissions in terms of "relevance". First, the PAR admissions (if there are more than one) are ranked based on admission date (earlier = higher rank). Ties are resolved by a diagnostic hierarchy.

# %%
query_TIME_HIERARCHY= query + "SELECT * FROM PR_ICU_ADMISSIONS_MATCHED_WITH_PAR_WITH_DX_TIME_HIERARCHY"
TIME_HIERARCHY  = pd.read_sql(query_TIME_HIERARCHY, engine)
count_id(TIME_HIERARCHY)
# Out:
# Unique patients: 7292 | Unique SIR admits: 7434 | Unique PAR admits: 7721

# %% [markdown]
# ### SUMMARY_TABLE and SUMMARY_TABLE_FIRST
# These tables add columns from PAR, DORS and SIR describing demographics and ICU admission status from the tables DESCRIPTIVE_PAR and DESCRIPTIVE_SIR. All rows with a PAR DX != ranked (based on time + dx hierarchy) as 1 are discharged.
#
# In SUMMARY_TABLE some "helper columns" are added to help with guessing the most relevant ICU admission for the transfer. Most patients have a Primary ICU admission and a PAR admission. But there are cases where patients are readmitted to the primary ICU in the days around the PAR admit. Also, in some cases patients are transferred between primary ICU's. The helper columns are:
# * rows_per_patient, keeps count of the number of entries per patient in the SUMMARY_TABLE. Helps with keeping track of patients that need further tie breakers.
# * earliest_par_admit_date, finds the earliest matched PAR admit date for the patient. Helps defining the "first ICU admission event", for example in the case where the patient is admitted in 2019 with an ASAH and in 2020 with HC.
# * par_admit_relative_sir_dsc, this is the difference in days between tertiary PAR admit and primary ICU discharge. Can be -1, 0, 1. (eg. 1 = Admitted to PAR the (calendar) day after PR ICU admission.)
# * icu_admit_rank, grouped on patient ID (LopNr) the par_admit_relative_sir_dsc is used to rank pairs of PRICU-PAR admissions. par_admit_relative_sir_dsc = 0 (same day) gets the highest rank, followed by par_admit_relative_sir_dsc = 1 (PAR admission day after a PRICU discharge) and -1 (PAR admission day before a PRICU discharge). This will help guessing the most relevant ICU admission for the transfer in case of readmissions et cetera. If tied (eg. two admissions on the transfer day) the PR ICU admit with the latest discharge time (hrs:min) will be ranked higher.
#
# In the SUMMARY_TABLE_FIRST table, only the PRICU-PAR pairs matching the earliest_par_admit_date are selected. Finally the highest ranking PRICU-PAR pair based on icu_admit_rank is choosen for each patient. Note that this does not come with any *guarantees* about correct PRICU-PAR pairings, but it's my best *guess*. There are some missclassified patients, for example a case where a patient is transferred from Bollnäs (discharged day 0) -> Gävle (discharged day 1) -> Uppsala (admitted day 0). Here the ranking mechanism will infer that the transfer is from Bollnäs -> Uppsala. However, handling this correctly would mean introduction of new concepts (such as a hierarchical ranking of primary ICUs) which will further increase complexity to handle a few edge cases.

# %%
query_DESC_PAR = query + "SELECT * FROM SUMMARY_TABLE_FIRST"
DESC = pd.read_sql(query_DESC_PAR, engine)

# format time
DESC['par_adm_date'] = pd.to_datetime(DESC['par_adm_date'], unit='D')
DESC['par_dsc_date'] = pd.to_datetime(DESC['par_dsc_date'], unit='D')
DESC['earliest_par_admit_date'] = pd.to_datetime(DESC['earliest_par_admit_date'], unit='D')

DESC['sir_adm_time'] = pd.to_datetime(DESC['sir_adm_time'], unit='s')
DESC['sir_dsc_time'] = pd.to_datetime(DESC['sir_dsc_time'], unit='s')
DESC['sir_adm_year'] = DESC['sir_adm_time'].dt.year

count_id(DESC)
# Out:
# Unique patients: 7292 | Unique SIR admits: 7292 | Unique PAR admits: 7292

# %%
#Let's take a look a slightly controversial group: the patients discharged from a primary ICU on day 0 and admitted to a tertiary center on day -1.

# %%
DESC[['LopNr', 'sir_adm_time', 'sir_dsc_time', 'par_adm_date', 'par_dsc_date', 'sir_icu_name', 'par_tertiary_center', 'DX_GROUP', 'rows_per_patient', 'par_admit_relative_sir_dsc', 'earliest_par_admit_date']].query("par_admit_relative_sir_dsc == -1").iloc[120:160]
# Out:
#         LopNr        sir_adm_time        sir_dsc_time par_adm_date  \
# 4129  37069.0 2018-03-18 03:00:00 2018-03-18 04:30:00   2018-03-17
# 4131  37091.0 2011-07-16 15:16:00 2011-07-17 14:35:00   2011-07-16
# 4139  37142.0 2019-06-30 16:30:00 2019-07-01 15:25:00   2019-06-30
# 4154  37252.0 2021-10-13 19:15:00 2021-10-14 16:00:00   2021-10-13
# 4236  37838.0 2018-01-05 22:15:00 2018-01-06 01:00:00   2018-01-05
# 4364  38617.0 2021-02-24 21:00:00 2021-02-25 01:00:00   2021-02-24
# 4397  38854.0 2020-10-11 02:30:00 2020-10-11 05:00:00   2020-10-10
# 4464  39280.0 2012-11-23 00:44:00 2012-11-23 10:12:00   2012-11-22
# 4519  39764.0 2013-01-11 21:30:00 2013-01-12 00:40:00   2013-01-11
# 4533  39953.0 2018-07-20 14:17:00 2018-07-21 01:38:00   2018-07-20
# 4534  39960.0 2013-05-29 19:37:00 2013-05-30 15:37:00   2013-05-29
# 4659  41286.0 2010-03-07 20:36:00 2010-03-08 18:41:00   2010-03-07
# 4673  41445.0 2010-04-21 04:15:00 2010-04-21 12:25:00   2010-04-20
# 4714  41753.0 2018-09-26 00:30:00 2018-09-26 14:30:00   2018-09-25
# 4758  42178.0 2020-05-08 12:00:00 2020-05-09 11:00:00   2020-05-08
# 4848  42932.0 2021-03-05 18:30:00 2021-03-06 08:30:00   2021-03-05
# 4853  42991.0 2013-01-23 16:42:00 2013-01-24 10:05:00   2013-01-23
# 4855  43004.0 2016-06-06 23:30:00 2016-06-07 02:30:00   2016-06-06
# 4857  43052.0 2018-08-06 10:07:00 2018-08-06 17:00:00   2018-08-05
# 4859  43061.0 2011-11-19 02:28:00 2011-11-19 03:21:00   2011-11-18
# 4870  43157.0 2010-10-20 20:10:00 2010-10-21 17:24:00   2010-10-20
# 4881  43324.0 2017-10-26 11:00:00 2017-10-26 15:37:00   2017-10-25
# 4885  43349.0 2011-02-02 21:31:00 2011-02-03 15:30:00   2011-02-02
# 4897  43447.0 2019-02-28 20:15:00 2019-03-01 17:35:00   2019-02-28
# 4915  43631.0 2015-06-16 15:35:00 2015-06-17 14:02:00   2015-06-16
# 4927  43736.0 2015-03-14 22:00:00 2015-03-15 05:00:00   2015-03-14
# 4929  43742.0 2022-05-24 19:20:00 2022-05-25 09:15:00   2022-05-24
# 4936  43784.0 2019-03-04 21:45:00 2019-03-05 02:20:00   2019-03-04
# 4979  44110.0 2012-11-10 13:29:00 2012-11-11 00:09:00   2012-11-10
# 5002  44345.0 2015-12-10 00:30:00 2015-12-10 02:30:00   2015-12-09
# 5065  44720.0 2019-08-03 23:00:00 2019-08-04 03:40:00   2019-08-03
# 5077  44804.0 2011-06-07 21:50:00 2011-06-08 00:00:00   2011-06-07
# 5090  44872.0 2012-12-06 22:20:00 2012-12-07 00:15:00   2012-12-06
# 5106  44973.0 2017-12-05 21:15:00 2017-12-06 00:30:00   2017-12-05
# 5207  45764.0 2018-02-26 01:15:00 2018-02-26 02:15:00   2018-02-25
# 5283  46667.0 2012-11-19 17:12:00 2012-11-19 19:30:00   2012-11-18
# 5291  46755.0 2011-02-19 21:13:00 2011-02-20 12:56:00   2011-02-19
# 5330  47124.0 2019-04-17 21:57:00 2019-04-18 02:14:00   2019-04-17
# 5338  47189.0 2010-12-17 15:59:00 2010-12-18 13:20:00   2010-12-17
# 5340  47206.0 2020-05-09 22:15:00 2020-05-10 03:30:00   2020-05-09
#
#      par_dsc_date    sir_icu_name                      par_tertiary_center  \
# 4129   2018-03-18       SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 4131   2011-07-16  NU Trollhättan        Sahlgrenska universitetssjukhuset
# 4139   2019-07-02       SU/IVA-MS        Sahlgrenska universitetssjukhuset
# 4154   2021-10-22      SU/IVA-INF        Sahlgrenska universitetssjukhuset
# 4236   2018-01-18          IVAUSÖ                     Akademiska sjukhuset
# 4364   2021-03-03   Sundsvall IVA            Norrlands universitetssjukhus
# 4397   2020-10-15       Östersund            Norrlands universitetssjukhus
# 4464   2012-11-23       SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 4519   2013-01-29  IVA Hudiksvall                     Akademiska sjukhuset
# 4533   2018-07-22          SÖSIVA  Karolinska universitetssjukhuset, Solna
# 4534   2013-05-30       SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 4659   2010-03-13       SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 4673   2010-04-21       SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 4714   2018-09-28       SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 4758   2020-05-12        IVA UMAS             Universitetssjukhuset i Lund
# 4848   2021-03-06      SU/IVA-INF        Sahlgrenska universitetssjukhuset
# 4853   2013-02-01      SU/IVA-INF        Sahlgrenska universitetssjukhuset
# 4855   2016-06-23      Eskilstuna                     Akademiska sjukhuset
# 4857   2018-08-06       SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 4859   2011-11-19       SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 4870   2010-10-25       SU/IVA-MS        Sahlgrenska universitetssjukhuset
# 4881   2017-10-27      SU/IVA-INF        Sahlgrenska universitetssjukhuset
# 4885   2011-02-03       SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 4897   2019-03-03       SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 4915   2015-06-29      SU/IVA-INF        Sahlgrenska universitetssjukhuset
# 4927   2015-03-24    Karlstad-IVA                     Akademiska sjukhuset
# 4929   2022-05-28    Karlstad-IVA                     Akademiska sjukhuset
# 4936   2019-03-05       SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 4979   2012-12-19     SÖS Med IVA  Karolinska universitetssjukhuset, Solna
# 5002   2015-12-20        Västerås                     Akademiska sjukhuset
# 5065   2019-08-07       IVA Falun                     Akademiska sjukhuset
# 5077   2011-06-10       IVA Falun                     Akademiska sjukhuset
# 5090   2012-12-21         Bollnäs                     Akademiska sjukhuset
# 5106   2017-12-06       SU/IVA-MS        Sahlgrenska universitetssjukhuset
# 5207   2018-02-26       SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 5283   2012-11-19  NU Trollhättan        Sahlgrenska universitetssjukhuset
# 5291   2011-03-02       SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 5330   2019-05-28     SÖS Med IVA  Karolinska universitetssjukhuset, Solna
# 5338   2010-12-28       SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 5340   2020-05-25   Sundsvall IVA            Norrlands universitetssjukhus
#
#      DX_GROUP  rows_per_patient  par_admit_relative_sir_dsc  \
# 4129      TBI                 1                          -1
# 4131      ABM                 1                          -1
# 4139      SEP                 2                          -1
# 4154      ABM                 1                          -1
# 4236     ASAH                 1                          -1
# 4364      ICH                 1                          -1
# 4397      SDH                 1                          -1
# 4464      TBI                 1                          -1
# 4519     ASAH                 1                          -1
# 4533      ABM                 1                          -1
# 4534      TBI                 1                          -1
# 4659      AIS                 1                          -1
# 4673      ABM                 1                          -1
# 4714     ASAH                 1                          -1
# 4758      SEP                 1                          -1
# 4848      ENC                 1                          -1
# 4853      ABM                 1                          -1
# 4855     ASAH                 1                          -1
# 4857      TBI                 1                          -1
# 4859      ICH                 1                          -1
# 4870      SEP                 1                          -1
# 4881      SEP                 1                          -1
# 4885      TBI                 1                          -1
# 4897      TUM                 1                          -1
# 4915      ABM                 1                          -1
# 4927      TUM                 1                          -1
# 4929      TBI                 1                          -1
# 4936      ICH                 1                          -1
# 4979      ICH                 1                          -1
# 5002      TBI                 1                          -1
# 5065      TBI                 1                          -1
# 5077     ASAH                 1                          -1
# 5090      ICH                 1                          -1
# 5106      SEP                 1                          -1
# 5207      TBI                 1                          -1
# 5283     ASAH                 1                          -1
# 5291      TBI                 1                          -1
# 5330      ABM                 1                          -1
# 5338      ABM                 1                          -1
# 5340      TBI                 1                          -1
#
#      earliest_par_admit_date
# 4129              2018-03-17
# 4131              2011-07-16
# 4139              2019-06-30
# 4154              2021-10-13
# 4236              2018-01-05
# 4364              2021-02-24
# 4397              2020-10-10
# 4464              2012-11-22
# 4519              2013-01-11
# 4533              2018-07-20
# 4534              2013-05-29
# 4659              2010-03-07
# 4673              2010-04-20
# 4714              2018-09-25
# 4758              2020-05-08
# 4848              2021-03-05
# 4853              2013-01-23
# 4855              2016-06-06
# 4857              2018-08-05
# 4859              2011-11-18
# 4870              2010-10-20
# 4881              2017-10-25
# 4885              2011-02-02
# 4897              2019-02-28
# 4915              2015-06-16
# 4927              2015-03-14
# 4929              2022-05-24
# 4936              2019-03-04
# 4979              2012-11-10
# 5002              2015-12-09
# 5065              2019-08-03
# 5077              2011-06-07
# 5090              2012-12-06
# 5106              2017-12-05
# 5207              2018-02-25
# 5283              2012-11-18
# 5291              2011-02-19
# 5330              2019-04-17
# 5338              2010-12-17
# 5340              2020-05-09

# %% [markdown]
# Looking at 80 of these transfers (>200 in total) around 12 look suspicious: these could be transfers going in the other direction (eg. a patient going directly from the primary (or tertiary) EMERGENCY DEPT -> Tertiary ICU -> Primary ICU and discharged from the primary ICU early). Luckily, most of these are "short distance transfers" (SÖS->KS, Östra->Sahlgrenska) with 1-2 exceptions. The vast majority of longer transfers seem relevant as they stay in the tertiary center for several days.
#
# An interesting observation is that most obviously relevant pairs have PR ICU discharges typically between 12 pm and 3 am, which makes sense. This is in contrast with the suspicious pars where the ICU discharge is typically in the afternoon (which also makes sense if the patient travelled in the direction Tertiary center -> PR ICU -> discharged from PR ICU). In order to decrease the number of false positive transfers, adding the condition of dsc between 00:00 and 04:00 will help.
#
# It's also worth noting that in the cases where the patient has their tertiary PAR admit the day after the PR ICU discharge, the PR ICU discharge time is almost always in >10 pm which makes perfect sense.

# %%
query_DESC_pruned = query + "SELECT * FROM FINAL"
DESC_pruned = pd.read_sql(query_DESC_pruned, engine)

# format time
DESC_pruned['par_adm_date'] = pd.to_datetime(DESC_pruned['par_adm_date'], unit='D')
DESC_pruned['par_dsc_date'] = pd.to_datetime(DESC_pruned['par_dsc_date'], unit='D')
DESC_pruned['earliest_par_admit_date'] = pd.to_datetime(DESC_pruned['earliest_par_admit_date'], unit='D')

DESC_pruned['sir_adm_time'] = pd.to_datetime(DESC_pruned['sir_adm_time'], unit='s')
DESC_pruned['sir_dsc_time'] = pd.to_datetime(DESC_pruned['sir_dsc_time'], unit='s')
DESC_pruned['sir_adm_year'] = DESC_pruned['sir_adm_time'].dt.year

count_id(DESC_pruned)
# Out:
# Unique patients: 7181 | Unique SIR admits: 7181 | Unique PAR admits: 7181

# %% [markdown]
# This is the result of the pruned table looking a patients with par_admit_relative_sir_dsc = -1:

# %%
DESC_pruned[['LopNr', 'sir_adm_time', 'sir_dsc_time', 'par_adm_date', 'par_dsc_date', 'sir_icu_name', 'par_tertiary_center', 'DX_GROUP', 'rows_per_patient', 'par_admit_relative_sir_dsc', 'earliest_par_admit_date']].query("par_admit_relative_sir_dsc == -1").head(40)
# Out:
#         LopNr        sir_adm_time        sir_dsc_time par_adm_date  \
# 7067    695.0 2016-04-06 17:15:00 2016-04-07 00:45:00   2016-04-06
# 7068    722.0 2020-05-24 21:00:00 2020-05-25 00:40:00   2020-05-24
# 7069    729.0 2020-10-05 22:50:00 2020-10-06 00:05:00   2020-10-05
# 7070    874.0 2021-03-13 18:00:00 2021-03-14 00:40:00   2021-03-13
# 7071   1175.0 2017-04-30 19:40:00 2017-05-01 00:15:00   2017-04-30
# 7072   1409.0 2019-03-11 13:45:00 2019-03-12 01:00:00   2019-03-11
# 7073   2929.0 2011-07-31 20:50:00 2011-08-01 00:58:00   2011-07-31
# 7074   3446.0 2016-01-18 20:20:00 2016-01-19 00:01:00   2016-01-18
# 7075   3558.0 2016-05-03 20:00:00 2016-05-04 01:30:00   2016-05-03
# 7076   4567.0 2012-05-13 20:45:00 2012-05-14 01:00:00   2012-05-13
# 7077   4604.0 2021-09-20 23:08:00 2021-09-21 00:58:00   2021-09-20
# 7078   4609.0 2019-04-18 19:58:00 2019-04-19 01:00:00   2019-04-18
# 7079   4985.0 2016-01-01 17:45:00 2016-01-02 00:50:00   2016-01-01
# 7080   5445.0 2013-12-16 23:45:00 2013-12-17 00:30:00   2013-12-16
# 7081   5675.0 2020-11-18 17:53:00 2020-11-19 01:34:00   2020-11-18
# 7082   6056.0 2020-07-02 21:10:00 2020-07-03 01:55:00   2020-07-02
# 7083   6196.0 2011-07-15 20:30:00 2011-07-16 00:22:00   2011-07-15
# 7084   7403.0 2016-01-25 22:30:00 2016-01-26 00:25:00   2016-01-25
# 7085   7566.0 2014-12-03 21:30:00 2014-12-04 00:00:00   2014-12-03
# 7086  10241.0 2014-09-02 16:36:00 2014-09-03 03:05:00   2014-09-02
# 7087  10322.0 2013-03-25 20:55:00 2013-03-26 01:45:00   2013-03-25
# 7088  10502.0 2017-05-26 03:00:00 2017-05-27 01:20:00   2017-05-26
# 7089  11305.0 2017-06-05 23:53:00 2017-06-06 01:10:00   2017-06-05
# 7090  11369.0 2016-01-20 22:10:00 2016-01-21 02:00:00   2016-01-20
# 7091  12197.0 2010-01-05 21:20:00 2010-01-06 00:05:00   2010-01-05
# 7092  12277.0 2010-07-15 23:00:00 2010-07-16 00:00:00   2010-07-15
# 7093  12403.0 2017-05-31 21:50:00 2017-06-01 01:15:00   2017-05-31
# 7094  13345.0 2022-01-29 20:30:00 2022-01-30 02:30:00   2022-01-29
# 7095  13422.0 2020-12-28 20:45:00 2020-12-29 03:00:00   2020-12-28
# 7096  13632.0 2022-01-18 21:33:00 2022-01-19 01:36:00   2022-01-18
# 7097  14120.0 2019-07-28 01:00:00 2019-07-29 00:56:00   2019-07-28
# 7098  14398.0 2013-11-20 22:04:00 2013-11-21 03:59:00   2013-11-20
# 7099  14588.0 2014-03-10 13:33:00 2014-03-11 03:57:00   2014-03-10
# 7100  14895.0 2017-10-02 22:45:00 2017-10-03 00:18:00   2017-10-02
# 7101  15881.0 2019-12-10 20:45:00 2019-12-11 01:30:00   2019-12-10
# 7102  17163.0 2014-07-31 21:00:00 2014-08-01 00:45:00   2014-07-31
# 7103  17663.0 2014-02-28 22:01:00 2014-03-01 03:51:00   2014-02-28
# 7104  18425.0 2011-05-26 15:45:00 2011-05-27 01:45:00   2011-05-26
# 7105  19039.0 2022-06-08 20:55:00 2022-06-09 00:20:00   2022-06-08
# 7106  19084.0 2015-05-01 20:20:00 2015-05-02 02:10:00   2015-05-01
#
#      par_dsc_date      sir_icu_name                      par_tertiary_center  \
# 7067   2016-04-08        Eskilstuna                     Akademiska sjukhuset
# 7068   2020-06-02        Eskilstuna                     Akademiska sjukhuset
# 7069   2020-10-13         IVA Falun                     Akademiska sjukhuset
# 7070   2021-03-16          Västerås                     Akademiska sjukhuset
# 7071   2017-05-06           Bollnäs                     Akademiska sjukhuset
# 7072   2019-03-15            Kalmar        Universitetssjukhuset i Linköping
# 7073   2011-08-01         SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 7074   2016-01-28           Varberg        Sahlgrenska universitetssjukhuset
# 7075   2016-05-15           Varberg        Sahlgrenska universitetssjukhuset
# 7076   2012-06-01     Sundsvall IVA            Norrlands universitetssjukhus
# 7077   2021-09-22             Gävle                     Akademiska sjukhuset
# 7078   2019-04-29            Kalmar        Universitetssjukhuset i Linköping
# 7079   2016-01-13         IVA Falun                     Akademiska sjukhuset
# 7080   2013-12-25  Örnsköldsvik IVA            Norrlands universitetssjukhus
# 7081   2020-11-23        Skellefteå            Norrlands universitetssjukhus
# 7082   2020-07-17          Sunderby            Norrlands universitetssjukhus
# 7083   2011-07-18          Sunderby            Norrlands universitetssjukhus
# 7084   2016-02-04      Karlstad-IVA                     Akademiska sjukhuset
# 7085   2014-12-16    IVA Hudiksvall                     Akademiska sjukhuset
# 7086   2014-09-03       SÖS Med IVA  Karolinska universitetssjukhuset, Solna
# 7087   2013-03-27           Varberg        Sahlgrenska universitetssjukhuset
# 7088   2017-05-27         SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 7089   2017-06-21            IVAKGA                     Akademiska sjukhuset
# 7090   2016-01-29      Karlstad-IVA                     Akademiska sjukhuset
# 7091   2010-01-08             Gävle                     Akademiska sjukhuset
# 7092   2010-07-21             Gävle  Karolinska universitetssjukhuset, Solna
# 7093   2017-06-01         SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 7094   2022-02-12         Östersund            Norrlands universitetssjukhus
# 7095   2021-01-19        Eskilstuna                     Akademiska sjukhuset
# 7096   2022-02-14          Lycksele            Norrlands universitetssjukhus
# 7097   2019-07-29          Sunderby            Norrlands universitetssjukhus
# 7098   2013-11-27            SÖSIVA  Karolinska universitetssjukhuset, Solna
# 7099   2014-03-19       SÖS Med IVA  Karolinska universitetssjukhuset, Solna
# 7100   2017-11-27          IVA Mora                     Akademiska sjukhuset
# 7101   2019-12-23     IVA Västervik        Universitetssjukhuset i Linköping
# 7102   2014-08-14           Varberg        Sahlgrenska universitetssjukhuset
# 7103   2014-03-27       SÖS Med IVA  Karolinska universitetssjukhuset, Solna
# 7104   2011-05-31      Karlstad-IVA                     Akademiska sjukhuset
# 7105   2022-06-18         IVA Falun                     Akademiska sjukhuset
# 7106   2015-05-06           Bollnäs  Karolinska universitetssjukhuset, Solna
#
#      DX_GROUP  rows_per_patient  par_admit_relative_sir_dsc  \
# 7067      TBI                 1                          -1
# 7068      ICH                 1                          -1
# 7069      ICH                 1                          -1
# 7070      TBI                 1                          -1
# 7071      TBI                 1                          -1
# 7072      TBI                 1                          -1
# 7073      TBI                 1                          -1
# 7074     ASAH                 1                          -1
# 7075      ICH                 1                          -1
# 7076      ICH                 1                          -1
# 7077      ICH                 1                          -1
# 7078     ASAH                 1                          -1
# 7079      CFX                 1                          -1
# 7080     ASAH                 1                          -1
# 7081      TBI                 1                          -1
# 7082     ASAH                 1                          -1
# 7083      TBI                 1                          -1
# 7084      ICH                 1                          -1
# 7085      SDH                 1                          -1
# 7086      ICH                 1                          -1
# 7087      SDH                 1                          -1
# 7088     ASAH                 1                          -1
# 7089     ASAH                 1                          -1
# 7090      ICH                 1                          -1
# 7091      CFX                 1                          -1
# 7092     ASAH                 1                          -1
# 7093      TBI                 1                          -1
# 7094     ASAH                 1                          -1
# 7095      TBI                 1                          -1
# 7096       HC                 1                          -1
# 7097      CFX                 1                          -1
# 7098      TBI                 1                          -1
# 7099      TBI                 1                          -1
# 7100     ASAH                 1                          -1
# 7101     ASAH                 1                          -1
# 7102     ASAH                 1                          -1
# 7103      ICH                 1                          -1
# 7104      ABM                 1                          -1
# 7105      TBI                 1                          -1
# 7106      ICH                 1                          -1
#
#      earliest_par_admit_date
# 7067              2016-04-06
# 7068              2020-05-24
# 7069              2020-10-05
# 7070              2021-03-13
# 7071              2017-04-30
# 7072              2019-03-11
# 7073              2011-07-31
# 7074              2016-01-18
# 7075              2016-05-03
# 7076              2012-05-13
# 7077              2021-09-20
# 7078              2019-04-18
# 7079              2016-01-01
# 7080              2013-12-16
# 7081              2020-11-18
# 7082              2020-07-02
# 7083              2011-07-15
# 7084              2016-01-25
# 7085              2014-12-03
# 7086              2014-09-02
# 7087              2013-03-25
# 7088              2017-05-26
# 7089              2017-06-05
# 7090              2016-01-20
# 7091              2010-01-05
# 7092              2010-07-15
# 7093              2017-05-31
# 7094              2022-01-29
# 7095              2020-12-28
# 7096              2022-01-18
# 7097              2019-07-28
# 7098              2013-11-20
# 7099              2014-03-10
# 7100              2017-10-02
# 7101              2019-12-10
# 7102              2014-07-31
# 7103              2014-02-28
# 7104              2011-05-26
# 7105              2022-06-08
# 7106              2015-05-01

# %% [markdown]
# Looks ok! Now for a quick summary of the patients:

# %%
s = DESC_pruned.groupby('DX_GROUP').agg({'age': 'mean', 'sex_female': 'mean', 'sir_total_time': 'median', 'SAPS_GCS': 'median', 'any_AMV': 'mean', 'd30': 'mean', 'VtfId_LopNr': 'count'})
s.rename(columns={'VtfId_LopNr': 'n'}).sort_values(by='n', ascending=False)
# Out:
#                 age  sex_female  sir_total_time  SAPS_GCS   any_AMV       d30  \
# DX_GROUP
# TBI       57.288745    0.267989           180.0      12.0  0.607011  0.126845
# ASAH      58.954186    0.629525           110.0      12.0  0.470588  0.163462
# ICH       58.462490    0.403712           135.0      10.0  0.650425  0.204176
# AIS       64.077961    0.344828           110.0      13.0  0.406297  0.262369
# SDH       67.852868    0.281796           162.0      11.0  0.376559  0.104738
# ABM       54.933908    0.442529           340.0      11.0  0.678161  0.112069
# CFX       57.673835    0.229391           442.0      15.0  0.254480  0.071685
# TUM       49.347826    0.380435           142.5       8.0  0.467391  0.152174
# HC        54.645833    0.416667           182.5       9.0  0.541667  0.020833
# SEP       57.731707    0.414634           440.0       6.0  0.439024  0.024390
# CVT       43.967742    0.548387           220.0      14.0  0.322581  0.064516
# AVM       47.625000    0.333333           160.0      14.5  0.291667  0.041667
# ENC       41.761905    0.476190           695.0       8.0  0.523810  0.047619
#
#              n
# DX_GROUP
# TBI       2168
# ASAH      1768
# ICH       1293
# AIS        667
# SDH        401
# ABM        348
# CFX        279
# TUM         92
# HC          48
# SEP         41
# CVT         31
# AVM         24
# ENC         21

# %% [markdown]
# And a comparison with a Venn diagram vs. the old query.

# %%
with open('/Users/JO/PhD/neuro-ascertainment/candidate-queries/transferred-nsicu-cohort/transferred-cohort.sql', 'r') as file:
    old_query = file.read()

old_query = old_query + "SELECT * FROM SUMMARY_TABLE_FIRST_PRUNE_LATE"

OLD_DESC = pd.read_sql(old_query, engine)

OLD_DESC['par_adm_date'] = pd.to_datetime(OLD_DESC['par_adm_date'], unit='D')
OLD_DESC['par_dsc_date'] = pd.to_datetime(OLD_DESC['par_dsc_date'], unit='D')
OLD_DESC['sir_adm_time'] = pd.to_datetime(OLD_DESC['sir_adm_time'], unit='s').dt.normalize()

# %%
count_id(OLD_DESC)
# Out:
# Unique patients: 7181 | Unique SIR admits: 7181 | Unique PAR admits: 7181

# %%
from matplotlib_venn import venn2

# Extract the unique IDs
set1 = set(DESC['VtfId_LopNr'])
set2 = set(OLD_DESC['VtfId_LopNr'])

# Plot Venn diagram
plt.figure(figsize=(8, 8))
venn2([set1, set2], ('New df', 'Old df'))
plt.title('Venn Diagram of ICU Admissions')
plt.show()

# %% [markdown]
# Small differences, and most "new" cases seem reasonable.

# %%
exclusive_to_new = set1 - set2
exclusive_to_old = set2 - set1

# %%
exclusive_new = DESC[DESC['VtfId_LopNr'].isin(exclusive_to_new)]

# %%
exclusive_new[['LopNr', 'sir_adm_time', 'sir_dsc_time', 'par_adm_date', 'par_dsc_date', 'sir_icu_name', 'par_tertiary_center', 'DX_GROUP', 'rows_per_patient', 'par_admit_relative_sir_dsc', 'earliest_par_admit_date']].head(40)
# Out:
#         LopNr        sir_adm_time        sir_dsc_time par_adm_date  \
# 163    1714.0 2010-11-16 16:40:00 2010-11-17 14:39:00   2010-11-16
# 166    1753.0 2013-12-12 19:15:00 2013-12-13 11:00:00   2013-12-12
# 167    1760.0 2016-11-23 21:15:00 2016-11-24 14:02:00   2016-11-23
# 242    2368.0 2012-07-26 11:57:00 2012-07-26 22:15:00   2012-07-25
# 263    2556.0 2015-04-09 19:45:00 2015-04-10 16:05:00   2015-04-09
# 297    2805.0 2012-11-11 22:22:00 2012-11-12 14:00:00   2012-11-11
# 305    2885.0 2021-11-19 23:00:00 2021-11-20 12:50:00   2021-11-19
# 310    2958.0 2010-06-04 16:30:00 2010-06-05 13:27:00   2010-06-04
# 311    2960.0 2020-01-19 15:50:00 2020-01-20 15:10:00   2020-01-19
# 320    3098.0 2011-05-22 22:30:00 2011-05-23 14:05:00   2011-05-22
# 336    3262.0 2020-07-21 13:00:00 2020-07-22 06:00:00   2020-07-21
# 389    3716.0 2020-06-01 12:20:00 2020-06-01 15:10:00   2020-05-31
# 444    4229.0 2014-12-11 21:06:00 2014-12-12 12:45:00   2014-12-11
# 641    5558.0 2019-04-04 21:00:00 2019-04-05 11:30:00   2019-04-04
# 809    7234.0 2020-07-23 16:45:00 2020-07-23 18:15:00   2020-07-22
# 1007   9066.0 2012-01-01 03:05:00 2012-01-01 05:59:00   2011-12-31
# 1137  10360.0 2018-05-07 10:00:00 2018-05-07 11:00:00   2018-05-06
# 1217  11134.0 2010-08-11 17:24:00 2010-08-12 15:25:00   2010-08-11
# 1445  12622.0 2012-01-31 03:00:00 2012-01-31 15:43:00   2012-01-30
# 1546  13340.0 2019-08-16 12:30:00 2019-08-17 11:25:00   2019-08-16
# 1704  15009.0 2010-09-12 13:15:00 2010-09-13 13:00:00   2010-09-12
# 1719  15133.0 2019-06-25 19:45:00 2019-06-26 19:00:00   2019-06-25
# 1843  16332.0 2016-08-18 15:55:00 2016-08-18 16:50:00   2016-08-17
# 1925  17157.0 2014-05-30 14:32:00 2014-05-31 10:11:00   2014-05-30
# 1974  17578.0 2022-01-03 14:45:00 2022-01-04 14:15:00   2022-01-03
# 1980  17635.0 2011-10-02 17:00:00 2011-10-03 13:50:00   2011-10-02
# 1984  17654.0 2012-01-09 20:15:00 2012-01-10 13:50:00   2012-01-09
# 2009  17859.0 2019-10-13 23:10:00 2019-10-14 14:50:00   2019-10-13
# 2024  18050.0 2014-09-30 13:07:00 2014-10-01 13:00:00   2014-09-30
# 2097  18656.0 2018-10-08 19:00:00 2018-10-09 14:55:00   2018-10-08
# 2119  18800.0 2010-01-05 23:38:00 2010-01-06 20:25:00   2010-01-05
# 2342  20255.0 2017-06-18 23:10:00 2017-06-19 05:25:00   2017-06-18
# 2448  21363.0 2018-07-11 15:34:00 2018-07-12 11:00:00   2018-07-11
# 2513  22069.0 2019-06-15 21:45:00 2019-06-16 15:00:00   2019-06-15
# 2618  22983.0 2019-10-31 19:29:00 2019-11-01 06:59:00   2019-10-31
# 2636  23156.0 2011-02-08 01:32:00 2011-02-08 11:40:00   2011-02-07
# 2689  23752.0 2017-07-08 05:30:00 2017-07-08 10:50:00   2017-07-07
# 2714  24014.0 2016-03-20 16:45:00 2016-03-20 20:30:00   2016-03-19
# 3052  26734.0 2015-05-14 14:00:00 2015-05-15 12:50:00   2015-05-14
# 3118  27450.0 2012-03-10 22:54:00 2012-03-11 12:24:00   2012-03-10
#
#      par_dsc_date       sir_icu_name                      par_tertiary_center  \
# 163    2010-11-16             SÖSIVA  Karolinska universitetssjukhuset, Solna
# 166    2013-12-13          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 167    2016-12-01          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 242    2012-07-26          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 263    2015-04-09              Ystad             Universitetssjukhuset i Lund
# 297    2012-11-14          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 305    2021-11-30         SU/IVA-INF        Sahlgrenska universitetssjukhuset
# 310    2010-06-24          SU/IVA-MS        Sahlgrenska universitetssjukhuset
# 311    2020-02-07          SU/IVA-MS        Sahlgrenska universitetssjukhuset
# 320    2011-05-25          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 336    2020-07-26         SU/IVA-INF        Sahlgrenska universitetssjukhuset
# 389    2020-06-01          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 444    2014-12-22          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 641    2019-04-05          SU/IVA-MS        Sahlgrenska universitetssjukhuset
# 809    2020-07-23  Skaraborg-IVA SIL        Sahlgrenska universitetssjukhuset
# 1007   2012-01-02          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 1137   2018-05-07          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 1217   2010-08-31          SU/IVA-MS        Sahlgrenska universitetssjukhuset
# 1445   2012-02-02         SU/IVA-INF        Sahlgrenska universitetssjukhuset
# 1546   2019-08-18           Sunderby            Norrlands universitetssjukhus
# 1704   2010-09-12   IVA Kristianstad             Universitetssjukhuset i Lund
# 1719   2019-06-28          SU/IVA-MS        Sahlgrenska universitetssjukhuset
# 1843   2016-08-18          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 1925   2014-05-30         SU/IVA-INF        Sahlgrenska universitetssjukhuset
# 1974   2022-01-04          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 1980   2011-10-13          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 1984   2012-02-14          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 2009   2019-10-13            Varberg        Sahlgrenska universitetssjukhuset
# 2024   2014-10-01          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 2097   2018-10-10          SU/IVA-MS        Sahlgrenska universitetssjukhuset
# 2119   2010-01-06          SU/IVA-ÖS        Sahlgrenska universitetssjukhuset
# 2342   2017-06-28           Sunderby            Norrlands universitetssjukhus
# 2448   2018-07-11              H-IVA  Karolinska universitetssjukhuset, Solna
# 2513   2019-06-15        Helsingborg             Universitetssjukhuset i Lund
# 2618   2019-11-03              H-IVA  Karolinska universitetssjukhuset, Solna
# 2636   2011-02-09          SU/IVA-MS        Sahlgrenska universitetssjukhuset
# 2689   2017-07-08          SU/IVA-MS        Sahlgrenska universitetssjukhuset
# 2714   2016-03-20           Alingsås        Sahlgrenska universitetssjukhuset
# 3052   2015-06-26         SU/IVA-INF        Sahlgrenska universitetssjukhuset
# 3118   2012-03-10         SU/IVA-INF        Sahlgrenska universitetssjukhuset
#
#      DX_GROUP  rows_per_patient  par_admit_relative_sir_dsc  \
# 163       SEP                 1                          -1
# 166       SEP                 1                          -1
# 167       AIS                 1                          -1
# 242       TBI                 1                          -1
# 263       ICH                 1                          -1
# 297       TBI                 1                          -1
# 305       ABM                 1                          -1
# 310       AIS                 1                          -1
# 311       ICH                 1                          -1
# 320       TBI                 1                          -1
# 336       ABM                 1                          -1
# 389       SEP                 1                          -1
# 444       AIS                 1                          -1
# 641       SEP                 1                          -1
# 809       TBI                 1                          -1
# 1007      TBI                 1                          -1
# 1137      TUM                 1                          -1
# 1217      SEP                 1                          -1
# 1445      ENC                 1                          -1
# 1546      CFX                 1                          -1
# 1704      ICH                 1                          -1
# 1719      ICH                 1                          -1
# 1843      TBI                 1                          -1
# 1925      ABM                 1                          -1
# 1974      SDH                 1                          -1
# 1980      ABM                 1                          -1
# 1984      AIS                 1                          -1
# 2009      ICH                 1                          -1
# 2024      CFX                 1                          -1
# 2097      SEP                 1                          -1
# 2119      AIS                 1                          -1
# 2342      ICH                 1                          -1
# 2448     ASAH                 1                          -1
# 2513      TBI                 1                          -1
# 2618      ICH                 1                          -1
# 2636      ICH                 1                          -1
# 2689      ABM                 1                          -1
# 2714      TBI                 1                          -1
# 3052      ABM                 1                          -1
# 3118      ENC                 1                          -1
#
#      earliest_par_admit_date
# 163               2010-11-16
# 166               2013-12-12
# 167               2016-11-23
# 242               2012-07-25
# 263               2015-04-09
# 297               2012-11-11
# 305               2021-11-19
# 310               2010-06-04
# 311               2020-01-19
# 320               2011-05-22
# 336               2020-07-21
# 389               2020-05-31
# 444               2014-12-11
# 641               2019-04-04
# 809               2020-07-22
# 1007              2011-12-31
# 1137              2018-05-06
# 1217              2010-08-11
# 1445              2012-01-30
# 1546              2019-08-16
# 1704              2010-09-12
# 1719              2019-06-25
# 1843              2016-08-17
# 1925              2014-05-30
# 1974              2022-01-03
# 1980              2011-10-02
# 1984              2012-01-09
# 2009              2019-10-13
# 2024              2014-09-30
# 2097              2018-10-08
# 2119              2010-01-05
# 2342              2017-06-18
# 2448              2018-07-11
# 2513              2019-06-15
# 2618              2019-10-31
# 2636              2011-02-07
# 2689              2017-07-07
# 2714              2016-03-19
# 3052              2015-05-14
# 3118              2012-03-10

# %% [markdown]
# Checking vs Bollnäs IVA local registry:

# %%
DESC_pruned[['sir_adm_year','sir_adm_time', 'sir_dsc_time', 'par_adm_date', 'par_dsc_date', 'sir_icu_name', 'par_tertiary_center', 'DX_GROUP', 'any_AMV', 'd30']].query("sir_icu_name == 'Bollnäs'").query("sir_adm_year == 2017").sort_values(by='sir_adm_time')
# Out:
#       sir_adm_year        sir_adm_time        sir_dsc_time par_adm_date  \
# 7071          2017 2017-04-30 19:40:00 2017-05-01 00:15:00   2017-04-30
# 2788          2017 2017-05-18 22:30:00 2017-05-19 10:10:00   2017-05-19
# 5563          2017 2017-06-13 21:15:00 2017-06-13 22:35:00   2017-06-14
# 4895          2017 2017-06-16 09:15:00 2017-06-16 11:30:00   2017-06-16
# 2769          2017 2017-07-20 01:15:00 2017-07-20 03:15:00   2017-07-20
# 6491          2017 2017-07-28 16:00:00 2017-07-28 23:20:00   2017-07-29
# 6896          2017 2017-08-11 04:45:00 2017-08-11 05:55:00   2017-08-11
# 6928          2017 2017-11-03 08:10:00 2017-11-03 10:00:00   2017-11-03
# 6011          2017 2017-12-27 17:45:00 2017-12-27 20:31:00   2017-12-27
#
#      par_dsc_date sir_icu_name                par_tertiary_center DX_GROUP  \
# 7071   2017-05-06      Bollnäs               Akademiska sjukhuset      TBI
# 2788   2017-05-31      Bollnäs               Akademiska sjukhuset      ICH
# 5563   2017-06-22      Bollnäs               Akademiska sjukhuset     ASAH
# 4895   2017-06-21      Bollnäs               Akademiska sjukhuset      AIS
# 2769   2017-07-24      Bollnäs               Akademiska sjukhuset      SDH
# 6491   2017-08-02      Bollnäs  Universitetssjukhuset i Linköping     ASAH
# 6896   2017-08-22      Bollnäs               Akademiska sjukhuset     ASAH
# 6928   2017-11-04      Bollnäs               Akademiska sjukhuset      ICH
# 6011   2018-01-09      Bollnäs               Akademiska sjukhuset     ASAH
#
#       any_AMV  d30
# 7071        1    0
# 2788        1    0
# 5563        0    0
# 4895        0    0
# 2769        1    0
# 6491        0    0
# 6896        0    0
# 6928        0    1
# 6011        0    0

# %% [markdown]
# * 2022 (up to may): Finds 3/3 + 1 relevant AIS (intubated).
# * 2021: 7/7 + 1 relevant AIS.
# * 2020: 8/10 , + 2 relevant AIS. The 2 missing are not in our dataset, i.e. not a problem with the query.
# * 2019: 11/11, + 3 relevant AIS.
# * 2018: 3/3, + 2 relevant AIS + 2 relevant others.
# * 2017: 8/8, + 1 relevant ICH.
#
# SUM: Finds 40/42 + 12 extra patients.
